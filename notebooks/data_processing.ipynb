# %%
import pandas as pd
import numpy as np
import json
import glob
import re
import ast
from sklearn.preprocessing import MultiLabelBinarizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def load_dataset(folder_path):
    data = []
    json_files = sorted(glob.glob(f"{folder_path}/sample_*.json"))
    
    print(f"Loading {len(json_files)} files...")
    for json_file in json_files:
        with open(json_file, 'r', encoding='utf-8') as f:
            data.append(json.load(f))
    
    return data

data = load_dataset('/content/drive/MyDrive/code_classification_dataset')
df = pd.DataFrame(data)

# %%
def clean_text(text):
    if not text or not isinstance(text, str):
        return ""
    
    cleaned = text
    cleaned = re.sub(r'\$([^\$]+?)\$', r' \1 ', cleaned)
    cleaned = re.sub(r'\$\$\$([^\$]+?)\$\$\$', r' \1 ', cleaned)
    cleaned = re.sub(r'\\[ld]?dots', '...', cleaned)
    cleaned = re.sub(r'\\frac\{([^}]+)\}\{([^}]+)\}', r'\1 divided by \2', cleaned)
    cleaned = re.sub(r'\\sum', 'sum', cleaned)
    cleaned = re.sub(r'\\prod', 'product', cleaned)
    cleaned = re.sub(r'\\(le|leq)', '<=', cleaned)
    cleaned = re.sub(r'\\(ge|geq)', '>=', cleaned)
    cleaned = re.sub(r'\\n?eq', '!=', cleaned)
    cleaned = re.sub(r'\\times', '*', cleaned)
    cleaned = re.sub(r'\\cdot', '*', cleaned)
    cleaned = re.sub(r'\\[a-zA-Z]+\{([^}]+)\}', r'\1', cleaned)
    cleaned = re.sub(r'\\[a-zA-Z]+', '', cleaned)
    cleaned = re.sub(r'[^a-zA-Z0-9\s\+\-\*\/\=\<\>\!\.\,]', ' ', cleaned)
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    cleaned = cleaned.lower()
    
    return cleaned

# %%
df['description_clean'] = df['prob_desc_description'].fillna("").apply(clean_text)

# %%
df['code_clean'] = df['source_code'].fillna("").apply(clean_text)

# %%
focus_tags = ['math', 'graphs', 'strings', 'number theory',
              'trees', 'geometry', 'games', 'probabilities']

def parse_tags(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except Exception:
            return []
    return x

df["tags_list"] = df["tags"].apply(parse_tags)
df["tags_filtered"] = df["tags_list"].apply(
    lambda tags: [t for t in tags if t in focus_tags]
)

df_focus = df[df["tags_filtered"].map(len) > 0].reset_index(drop=True)

# %%
df_focus = pd.read_csv("/content/drive/MyDrive/code_classification_dataset/df_focus.csv")

# %%
df_focus
# Out:
#      prob_desc_time_limit                           prob_desc_sample_outputs  \
# 0               2 seconds                               ["2\n2 4\n3 3\n3 1"]
# 1               3 seconds                                    ["4\n10\n4\n0"]
# 2               2 seconds                                  ["5", "16", "18"]
# 3                1 second  ["2\n5000 9\n1\n7 \n4\n800 70 6 9000 \n1\n1000...
# 4                1 second                                         ["1", "0"]
# ...                   ...                                                ...
# 2673            2 seconds                        ["abac\nac\nbcdaf\nzzzzzz"]
# 2674            2 seconds                                      ["YES", "NO"]
# 2675            2 seconds                                    ["2", "0", "3"]
# 2676            2 seconds                                    ["2\n1\n-1\n0"]
# 2677            2 seconds               ["1.000000000000", "1.714285714286"]
#
#                                src_uid  \
# 0     591372383cf3624f69793c41370022de
# 1     afcd41492158e68095b01ff1e88c3dd4
# 2     e52ec2fa5bcf5d2027d57b0694b4e15a
# 3     cd2519f4a7888b2c292f05c64a9db13a
# 4     a34f2aa89fe0e78b495b20400d73acf1
# ...                                ...
# 2673  ac77e2e6c86b5528b401debe9f68fc8e
# 2674  c659bdeda1c1da08cfc7f71367222332
# 2675  c0c29565e465840103a4af884f951cda
# 2676  942123e43a83d5a4cea95a6781064e28
# 2677  a69b342ef5f6e11f7aa4fee71e149aa2
#
#                                         prob_desc_notes  \
# 0                                                   NaN
# 1     NoteIn the first test case of the example, the...
# 2     NoteIn the first example it is possible to con...
# 3                                                   NaN
# 4     NoteThe first test case corresponds to the tre...
# ...                                                 ...
# 2673  NoteThe first test case is explained in the st...
# 2674  Note  First example: you can simply swap two l...
# 2675  NoteIn the first example two seconds are neede...
# 2676  NoteIn the first test case, in the first move,...
# 2677  NoteIn the first sample you can put a police s...
#
#                                   prob_desc_description  \
# 0     Numbers $$$1, 2, 3, \dots n$$$ (each integer f...
# 1     There are $$$n$$$ positive integers $$$a_1, a_...
# 2     You are given an undirected graph consisting o...
# 3     A positive (strictly greater than zero) intege...
# 4     You are given a tree with $$$n$$$ vertices. Yo...
# ...                                                 ...
# 2673  Alice guesses the strings that Bob made for he...
# 2674  Some dwarves that are finishing the StUDY (Sta...
# 2675  In the school computer room there are n server...
# 2676  You are given an array $$$a[0 \ldots n-1]$$$ o...
# 2677  The Berland road network consists of n cities ...
#
#                                   prob_desc_output_spec  \
# 0     For each test case, in the first line, print t...
# 1     For $$$t$$$ test cases print the answers in th...
# 2     Print one integer — the minimum number of coin...
# 3     Print $$$t$$$ answers to the test cases. Each ...
# 4     Print a single integer  — the minimum number o...
# ...                                                 ...
# 2673  Output $$$t$$$ answers to test cases. Each ans...
# 2674  Print "YES", if the dwarves belong to the same...
# 2675  Print the minimum number of seconds required t...
# 2676  For each test case, output a single integer — ...
# 2677  Print the maximum possible value of the averag...
#
#                                    prob_desc_input_spec prob_desc_output_to  \
# 0     The first line contains one integer $$$t$$$ ($...     standard output
# 1     The first line of the input contains one integ...     standard output
# 2     The first line contains two integers $$$n$$$ a...     standard output
# 3     The first line contains an integer $$$t$$$ ($$...     standard output
# 4     The first line contains an integer $$$n$$$ ($$...     standard output
# ...                                                 ...                 ...
# 2673  The first line contains a single positive inte...     standard output
# 2674  The first line contains the first dwarf's geno...     standard output
# 2675  The first line contains positive number n (1 ≤...     standard output
# 2676  The first line contains a single integer $$$t$...     standard output
# 2677  The first input line contains two integers n a...     standard output
#
#      prob_desc_input_from      lang  ...  \
# 0          standard input  Python 3  ...
# 1          standard input  Python 3  ...
# 2          standard input  Python 3  ...
# 3          standard input    PyPy 3  ...
# 4          standard input    PyPy 3  ...
# ...                   ...       ...  ...
# 2673       standard input  Python 3  ...
# 2674       standard input  Python 3  ...
# 2675       standard input  Python 2  ...
# 2676       standard input  Python 3  ...
# 2677       standard input  Python 3  ...
#
#                                 prob_desc_sample_inputs  exec_outcome  \
# 0                                              ["1\n4"]        PASSED
# 1     ["4\n6\n40 6 40 3 20 1\n1\n1024\n4\n2 4 8 16\n...        PASSED
# 2     ["3 2\n1 3 3\n2 3 5\n2 1 1", "4 0\n1 3 3 7", "...        PASSED
# 3                       ["5\n5009\n7\n9876\n10000\n10"]        PASSED
# 4     ["6\n4 5\n2 6\n3 2\n1 2\n2 4", "4\n2 4\n4 1\n3...        PASSED
# ...                                                 ...           ...
# 2673            ["4\nabbaac\nac\nbccddaaf\nzzzzzzzzzz"]        PASSED
# 2674                               ["ab\nba", "aa\nab"]        PASSED
# 2675  ["2\n1 6", "7\n10 11 10 11 10 11 11", "5\n1 2 ...        PASSED
# 2676  ["4\n4\n3 2 7 6\n3\n3 2 6\n1\n7\n7\n4 9 2 1 18...        PASSED
# 2677  ["4 4\n1 2\n2 4\n1 3\n3 4", "11 14\n1 2\n1 3\n...        PASSED
#
#                                             source_code prob_desc_created_at  \
# 0     \ndef ii(): return int(input())\ndef mi(): ret...           1602407100
# 1     a = int(input())\nfor i in range(a):\n    f = ...           1576321500
# 2     def read_nums():\n    return [int(x) for x in ...           1545921300
# 3     t = int(input())\nfor i in range(t):\n    canP...           1590154500
# 4     import sys\nfrom collections import defaultdic...           1593873900
# ...                                                 ...                  ...
# 2673  x = int (input())\n\nz = [0 for i in range(x)]...           1592318100
# 2674  p=input()\np=p.replace('',' ')\np=p.split()\nq...           1336145400
# 2675  n = input()\nlst = map(float, raw_input().spli...           1450537200
# 2676  t = int(input())\nfor i in range(t):\n  n = in...           1592318100
# 2677  from collections import deque\n\nn, m = [int(i...           1343057400
#
#                                                    tags hidden_unit_tests  \
# 0     ['greedy', 'constructive algorithms', 'math', ...               NaN
# 1                           ['number theory', 'greedy']               NaN
# 2                           ['dsu', 'greedy', 'graphs']               NaN
# 3                            ['implementation', 'math']               NaN
# 4     ['graphs', 'constructive algorithms', 'graph m...               NaN
# ...                                                 ...               ...
# 2673                      ['implementation', 'strings']               NaN
# 2674                      ['implementation', 'strings']               NaN
# 2675                         ['implementation', 'math']               NaN
# 2676                                 ['greedy', 'math']               NaN
# 2677                 ['dp', 'graphs', 'shortest paths']               NaN
#
#                                       description_clean  \
# 0     numbers 1, 2, 3, ... n each integer from 1 to ...
# 1     there are n positive integers a 1, a 2, ..., a...
# 2     you are given an undirected graph consisting o...
# 3     a positive strictly greater than zero integer ...
# 4     you are given a tree with n vertices. you are ...
# ...                                                 ...
# 2673  alice guesses the strings that bob made for he...
# 2674  some dwarves that are finishing the study stat...
# 2675  in the school computer room there are n server...
# 2676  you are given an array a 0 ... n-1 of length n...
# 2677  the berland road network consists of n cities ...
#
#                                              code_clean  \
# 0     def ii return int input def mi return map int,...
# 1     a = int input for i in range a f = int input k...
# 2     def read nums return int x for x in input .spl...
# 3     t = int input for i in range t canprintlength ...
# 4     import sys from collections import defaultdict...
# ...                                                 ...
# 2673  x = int input z = 0 for i in range x for y in ...
# 2674  p=input p=p.replace , p=p.split q=input q=q.re...
# 2675  n = input lst = map float, raw input .split me...
# 2676  t = int input for i in range t n = int input l...
# 2677  from collections import deque n, m = int i for...
#
#                                               tags_list        tags_filtered
# 0     [constructive algorithms, data structures, gre...             ['math']
# 1                               [greedy, number theory]    ['number theory']
# 2                                 [dsu, graphs, greedy]           ['graphs']
# 3                                [implementation, math]             ['math']
# 4     [brute force, constructive algorithms, dfs and...  ['graphs', 'trees']
# ...                                                 ...                  ...
# 2673                          [implementation, strings]          ['strings']
# 2674                          [implementation, strings]          ['strings']
# 2675                             [implementation, math]             ['math']
# 2676                                     [greedy, math]             ['math']
# 2677                       [dp, graphs, shortest paths]           ['graphs']
#
# [2678 rows x 25 columns]

# %%
def parse_tags(x):
    if isinstance(x, list):
        return x
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return [t.strip(" '[]") for t in str(x).split(',') if t.strip(" '[]")]

df_focus['tags_filtered'] = df_focus['tags_filtered'].apply(parse_tags)
df_focus['tags_list'] = df_focus['tags_list'].apply(
    lambda lst: sorted(set(t.strip() for t in lst if t.strip()))
)

mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(df_focus['tags_filtered'])

print(Y.shape)
print(mlb.classes_)

# %%
feature_cols = ['description_clean', 'code_clean']
X = df_focus[feature_cols]

# %%
# !pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.9-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from iterative-stratification) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->iterative-stratification) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->iterative-stratification) (3.6.0)
# Downloading iterative_stratification-0.1.9-py3-none-any.whl (8.5 kB)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.9

# %%
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
msss = MultilabelStratifiedShuffleSplit(
    n_splits=1,
    test_size=0.2,
    random_state=42
)

for train_idx, test_idx in msss.split(X, Y):
    X_train = df_focus.iloc[train_idx]
    X_test  = df_focus.iloc[test_idx]
    Y_train = Y[train_idx]
    Y_test  = Y[test_idx]

# %%
train_df = df_focus.iloc[train_idx].copy()
test_df = df_focus.iloc[test_idx].copy()

# %%
def label_proportions(Y):
    return Y.sum(axis=0) / len(Y)

print("Full proportions:",  label_proportions(Y))
print("Train proportions:", label_proportions(Y_train))
print("Test proportions:",  label_proportions(Y_test))
# Out:
# Full proportions: [0.03920836 0.06198656 0.20238984 0.5257655  0.13069455 0.034354
#  0.15758028 0.12098581]
# Train proportions: [0.03912436 0.0619469  0.20214252 0.52445272 0.13041453 0.0344667
#  0.15742897 0.12063344]
# Test proportions: [0.03954802 0.06214689 0.20338983 0.53107345 0.13182674 0.03389831
#  0.15819209 0.12241055]

# %%
train_df.to_csv("/content/drive/MyDrive/code_classification_dataset/train_df.csv", index=False)
test_df.to_csv("/content/drive/MyDrive/code_classification_dataset/test_df.csv", index=False)
